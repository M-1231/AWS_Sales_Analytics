# %%
df=pd.read_csv("Sales_master_processed.csv")
df
# Out:
# C:\Users\shukl\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\shukl\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                          Source.Name   OrderDate   StockDate OrderNumber  \
# 0      AdventureWorks_Sales_2016.csv  2016-01-03  2002-09-06     SO48819
# 1      AdventureWorks_Sales_2016.csv  2016-01-13  2002-09-19     SO48901
# 2      AdventureWorks_Sales_2016.csv  2016-01-14  2002-09-22     SO48909
# 3      AdventureWorks_Sales_2016.csv  2016-01-16  2002-10-23     SO48929
# 4      AdventureWorks_Sales_2016.csv  2016-01-17  2002-12-17     SO48936
# ...

# %%
#Top 10 products by revenue
df.groupby(['ProductName','CategoryName','SubcategoryName'])['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# ProductName              CategoryName  SubcategoryName
# Mountain-200 Black, 46   Bikes         Mountain Bikes     1241754.6
# Mountain-200 Black, 42   Bikes         Mountain Bikes     1233558.2
# Mountain-200 Silver, 38  Bikes         Mountain Bikes     1213840.4
# Mountain-200 Silver, 46  Bikes         Mountain Bikes     1182769.4
# Mountain-200 Black, 38   Bikes         Mountain Bikes     1165937.9
# Mountain-200 Silver, 42  Bikes         Mountain Bikes     1133055.8
# Road-250 Black, 52       Bikes         Road Bikes          689385.6
# Road-250 Red, 58         Bikes         Road Bikes          661024.8
# Road-250 Black, 48       Bikes         Road Bikes          641390.4
# Road-150 Red, 48         Bikes         Road Bikes          640515.7
# Name: Sales, dtype: float64

# %% [markdown]
# Insight
#
# The business is highly dependent on the Mountain-200 product family.
#
# Business Recommendation
# Protect inventory availability of Mountain-200 models.
# Investigate why these models outperform others.
# Use them for bundle and cross-selling strategies.

# %%
#Top Categories by quantity
df.groupby('CategoryName')['OrderQuantity'].sum()
# Out:
# CategoryName
# Accessories    57809
# Bikes          13929
# Clothing       12436
# Name: OrderQuantity, dtype: int64

# %%
Important Business Insight

Accessories dominate volume but not revenue.

This means:High Volume,Low Price while Bikes are:Low Volume,High Revenue

# %%
#Top SubCategories by revenue
df.groupby('SubcategoryName')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# SubcategoryName
# Road Bikes           11287256.4
# Mountain Bikes        8583729.8
# Touring Bikes         3771610.1
# Tires and Tubes        381103.4
# Helmets                205681.0
# Jerseys                158632.5
# Bottles and Cages      107896.0
# Fenders                 87120.0
# Shorts                  66080.0
# Gloves                  62134.0
# Name: Sales, dtype: float64

# %% [markdown]
# Insight
#
# Let's estimate contribution:
#
# Road Bikes+ Mountain Bikes = ~80% of revenue
#
# The company is essentially a bike business.
#
# Accessories and clothing play supporting roles.
#
# Recommendation
#
# Create a strategy to increase accessory attachment rates.
#
# Example:
#
# Bike Purchase
# ↓
# Helmet Offer
# ↓
# Bottle Cage Offer
# ↓
# Gloves Offer
#
# Increasing accessory sales can improve profitability without needing more customers.

# %%
aws_sales=pd.read_excel("AWS_Sales.xlsx",
    sheet_name="aws_sales")

customers = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="customers"
)
calendar = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="calendar"
)
territories = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="territories"
)
products_cat = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="products_cat"
)
products_subcat = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="products_subcat"
)
products = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="products"
)
returns = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="returns"
)
product_master = (
    products
    .merge(
        products_subcat,
        on='ProductSubcategoryKey',
        how='left'
    )
    .merge(
        products_cat,
        on='ProductCategoryKey',
        how='left'
    )
)

# %%
returns_enriched=(returns.merge(product_master[['ProductKey','ProductName','ProductPrice']],
on='ProductKey',how='left'))

# %%
returns_enriched.groupby(['ProductKey','ProductName'])['ReturnQuantity'].sum().sort_values(ascending=False).head(10)
# Out:
# ProductKey  ProductName
# 477         Water Bottle - 30 oz.      155
# 480         Patch Kit/8 Patches         95
# 528         Mountain Tire Tube          93
# 478         Mountain Bottle Cage        77
# 214         Sport-100 Helmet, Red       70
# 529         Road Tire Tube              67
# 220         Sport-100 Helmet, Blue      66
# 479         Road Bottle Cage            56
# 485         Fender Set - Mountain       54
# 215         Sport-100 Helmet, Black     52
# Name: ReturnQuantity, dtype: int64

# %% [markdown]
# Observation
# Most returned products are accessories.
# But earlier we saw : Bikes generate most revenue and Accessories generate most volume.This suggests returns may simply be occurring because accessories sell in very high quantities.

# %%
aws_sales=pd.read_excel("AWS_Sales.xlsx",
    sheet_name="aws_sales")

customers = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="customers"
)
calendar = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="calendar"
)
territories = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="territories"
)
products_cat = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="products_cat"
)
products_subcat = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="products_subcat"
)
products = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="products"
)
returns = pd.read_excel(
    "AWS_Sales.xlsx",
    sheet_name="returns"
)
product_master = (
    products
    .merge(
        products_subcat,
        on='ProductSubcategoryKey',
        how='left'
    )
    .merge(
        products_cat,
        on='ProductCategoryKey',
        how='left'
    )
)
sales_master=(
    aws_sales.merge(customers,on='CustomerKey',how='left')
    .merge(product_master,on='ProductKey',how='left')
    .merge(territories,left_on='TerritoryKey',right_on='SalesTerritoryKey',how='left')
)
# Out:
# C:\Users\shukl\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\shukl\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Profit by Category
sales_master.groupby('CategoryName')['Profit_After_Discount'].sum().sort_values(ascending=False)
# Out:
# CategoryName
# Bikes          7362133.37
# Accessories     343082.99
# Clothing        103311.08
# Name: Profit_After_Discount, dtype: float64

# %% [markdown]
# Business Risk
# The company is heavily dependent on one category.
#
# If bike demand weakens:
# Revenue falls
# Profit falls
# Business performance is significantly impacted
#
# Recommendation
# Increase profitability from Accessories,Clothing through bundling and upselling.

# %%
#Profit by Country
sales_master.groupby('Country')['Profit_After_Discount'].sum().sort_values(ascending=False)
# Out:
# Country
# United States     2513838.29
# Australia         2304631.58
# United Kingdom     906714.14
# Germany            787047.67
# France             738377.83
# Canada             557917.93
# Name: Profit_After_Discount, dtype: float64

# %% [markdown]
# Insight
# The profit ranking mirrors the revenue ranking.
#
# This tells us:
# The strongest revenue markets are also the strongest profit markets

# %%
#Profit by Product
sales_master.groupby('ProductName')['Profit_After_Discount'].sum().sort_values(ascending=False).head(10)
# Out:
# ProductName
# Mountain-200 Black, 46     447464.34
# Mountain-200 Black, 42     444510.78
# Mountain-200 Silver, 38    437366.96
# Mountain-200 Silver, 46    426171.56
# Mountain-200 Black, 38     420143.91
# Mountain-200 Silver, 42    408258.92
# Road-250 Black, 52         203105.84
# Road-250 Red, 58           194750.22
# Road-250 Black, 48         188965.56
# Road-150 Red, 48           187801.43
# Name: Profit_After_Discount, dtype: float64

# %% [markdown]
# This suggests the Mountain-200 line is a strategic product family.

# %%
#Profit by Occupation
sales_master.groupby('Occupation')['Profit_After_Discount'].sum().sort_values(ascending=False)
# Out:
# Occupation
# Professional      2674976.23
# Skilled Manual    1673892.86
# Management        1463930.88
# Clerical          1233595.11
# Manual             762132.36
# Name: Profit_After_Discount, dtype: float64

# %%
Insight
Professionals are not only the highest revenue segment but also the most profitable.

Recommendation
Focus acquisition and retention efforts on:
Professional
Management
Skilled Manual

These are the highest-value customer segments

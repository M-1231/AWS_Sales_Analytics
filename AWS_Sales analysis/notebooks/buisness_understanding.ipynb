# %% [markdown]
# Buisness Overview
#
# What business are we analyzing? What company could this be?
#
# Answer: A retail company selling products globally.

# %%
Stakeholders

Who are the stakeholders?

CEO
Sales Manager
Marketing Manager
Product Manager
Regional Manager

What decisions do they want to make?

CEO
Is revenue growing?
Sales Manager
Which products sell best?
Marketing Manager
Which customers generate most revenue?
Product Manager
Which products are returned most?
Regional Manager
Which countries perform best?

# %% [markdown]
# Business Objective
#
# The objective was to identify revenue drivers, customer purchasing patterns, product performance, and return trends to support strategic business decisions.

# %%
KPI Definitions

KPI	            Definition	                Business Meaning
Revenue	        Sum of Sales	            Overall business performance
Orders	        Count of Orders	            Demand
Customers	    Distinct Customers	        Reach
AOV	            Revenue / Orders	        Order quality
Return Rate	    Returns / Sales Qty	        Product quality

# %%
Data Dictionary

Sales Table

What does each row represent?

Answer: One row = one product sold in one order


Customers Table

One row represents?

Answer: One customer


Products Table

Answer: One row = one product


Returns Table

Answer: One row = return transaction

# %%
Business Questions

Sales Questions
What is total revenue?
How does revenue change over time?
Which months perform best?

Customer Questions
Who are top customers?
Which age groups spend more?
Which occupations spend more?

Product Questions
Which products generate most revenue?
Which products are returned most?

Territory Questions
Which countries perform best?
Which regions underperform?

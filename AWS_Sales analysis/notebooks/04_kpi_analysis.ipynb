# %%
df=pd.read_csv("sales_master_processed.csv")
# Out:
# C:\Users\shukl\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\shukl\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df
# Out:
#                          Source.Name   OrderDate   StockDate OrderNumber  \
# 0      AdventureWorks_Sales_2016.csv  2016-01-03  2002-09-06     SO48819
# 1      AdventureWorks_Sales_2016.csv  2016-01-13  2002-09-19     SO48901
# 2      AdventureWorks_Sales_2016.csv  2016-01-14  2002-09-22     SO48909
# 3      AdventureWorks_Sales_2016.csv  2016-01-16  2002-10-23     SO48929
# 4      AdventureWorks_Sales_2016.csv  2016-01-17  2002-12-17     SO48936
# ...                              ...         ...         ...         ...
# 56041  AdventureWorks_Sales_2017.csv  2017-05-16  2004-02-16     SO70714
# 56042  AdventureWorks_Sales_2017.csv  2017-06-01  2004-04-12     SO71961
# 56043  AdventureWorks_Sales_2017.csv  2017-06-11  2004-04-11     SO72656
# 56044  AdventureWorks_Sales_2017.csv  2017-06-11  2004-05-27     SO72656
# 56045  AdventureWorks_Sales_2017.csv  2017-06-14  2004-05-14     SO72927
#
#        ProductKey  CustomerKey  TerritoryKey  OrderLineItem  OrderQuantity  \
# ...

# %%
#KPI 1- Total Revenue
df['Sales'].sum()
# Out:
# 24914911.3

# %%
#KPI 2- Total Orders
df['OrderNumber'].nunique()
# Out:
# 25164

# %%
#KPI 3- Customers
df['CustomerKey'].nunique()
# Out:
# 17416

# %%
#KPI 4- Products Sold
df['ProductKey'].nunique()
# Out:
# 130

# %%
#KPI 5- Quantity Sold
df['OrderQuantity'].sum()
# Out:
# 84174

# %%
#Revenue by Year
df.groupby('OrderYear')['Sales'].sum()
# Out:
# OrderYear
# 2015    6404980.9
# 2016    9324334.7
# 2017    9185595.7
# Name: Sales, dtype: float64

# %% [markdown]
# Business Insight
#
# 1.The company experienced very strong growth in 2016.
# 2.Revenue stabilized in 2017.
# 3.Growth momentum slowed significantly after 2016.
# 4.Management should investigate why growth plateaued.

# %%
#Revenue by Country
df.groupby('Country')['Sales'].sum()
# Out:
# Country
# Australia         7416533.4
# Canada            1769293.6
# France            2362671.6
# Germany           2524704.4
# United Kingdom    2902590.1
# United States     7939118.2
# Name: Sales, dtype: float64

# %% [markdown]
# Business Insight
#
# Top two markets:
# United States
# Australia
#
# Together they generate roughly: ~61% of total revenue
#
# This suggests:
# Strong brand presence
# Strong customer demand
# Potential benchmark markets
#
# Recommendation
# Analyze successful strategies in the US and Australia and replicate them in Canada, France, and Germany.

# %%
#Revenue by Category
df.groupby('CategoryName')['Sales'].sum()
# Out:
# CategoryName
# Accessories      907119.4
# Bikes          23642596.3
# Clothing         365195.6
# Name: Sales, dtype: float64

# %% [markdown]
# Business Insight
# The company is extremely dependent on Bikes.
# Risk:If bike demand decreases: Major revenue impact
#
# Recommendation
# Increase cross-selling of:
# 1.Accessories
# 2.Clothing
# to diversify revenue streams.

# %%
#Revenue by Occupation
df.groupby('Occupation')['Sales'].sum()
# Out:
# Occupation
# Clerical          3988416.3
# Management        4624996.4
# Manual            2464114.2
# Professional      8466268.1
# Skilled Manual    5371116.3
# Name: Sales, dtype: float64

# %%
Business Insight

Professionals generate the highest revenue.

This indicates:
Higher purchasing power
Greater interest in premium products

Recommendation

Create targeted marketing campaigns for:
Professional
Management
Skilled Manual segments.
